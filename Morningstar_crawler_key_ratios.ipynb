# %%
# install chromium, its driver, and selenium
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_experimental_option("prefs", {
  "download.default_directory": "/content",
  "download.prompt_for_download": False,
})
# open it, go to a website, and get results
#wd = webdriver.Chrome('chromedriver',options=options)
#wd.get("https://www.google.com")
#print(wd.page_source)  # results
# divs = wd.find_elements_by_css_selector('div')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 8 not upgraded.
# Need to get 65.8 MB of archives.
# After this operation, 234 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 76.0.3809.100-0ubuntu0.18.04.1 [1,066 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 76.0.3809.100-0ubuntu0.18.04.1 [57.5 MB]
# ...

# %%
import urllib.request
import selenium

ticker_dax =['XETR:ADS','XETR:ALV','XETR:BAS','XETR:BAYN','XETR:BEI','XETR:BMW','XETR:CON','XETR:1COV','XETR:DAI','XETR:DBK','XETR:DB1','XETR:LHA','XETR:DPW','XETR:DTE','XETR:EOAN','XETR:FRE','XETR:FME','XETR:HEI','XETR:HEN3','XETR:IFX','XETR:LIN','XETR:MRK','XETR:MUV2','XETR:RWE','XETR:SAP','XETR:SIE','XETR:TKA','XETR:VOW3','XETR:VNA','XETR:WDI']
ticker_mdax = ['XETR:GIL','XETR:DEQ','XETR:LXS','XETR:EVD','XETR:ARL','XETR:GXI','XETR:EVK','XETR:SHA','XETR:OSR','XETR:FRA','XETR:TEG','XETR:SZU','XETR:LEG','XETR:1COV','XETR:BOSS','XETR:HNR1','XETR:SNH','XETR:FIE','XETR:HOT','XETR:RRTL','XETR:KRN','XETR:ZAL','XETR:KGX','XETR:NOEJ','XETR:FPE3','XETR:RHK','XETR:DUE','XETR:JUN3']
ticker_tdax =['XETR:O1BC','XETR:GFT','XETR:QIA','XETR:PFV','XETR:SBS','XETR:MOR','XETR:COK','XETR:DRW3','XETR:DLG','XETR:ADV','XETR:COP','XETR:BC8','XETR:NDX1','XETR:EVT','XETR:AFX','XETR:WAF','XETR:FNTN','XETR:SOW','XETR:SRT3','XETR:WDI','XETR:SMHN','XETR:S92','XETR:O2D','XETR:AM3D','XETR:RIB','XETR:AIXA','XETR:DRI','XETR:UTDI','XETR:JEN','XETR:NEM']
ticker_test = ['XETR:MTX']

report_type ='is'
region='usa'
culture='en-US'
currency ='EUR'

d = webdriver.Chrome('chromedriver',options=options)

d.command_executor._commands["send_command"] = ("POST", '/session/$sessionId/chromium/send_command')

params = {'cmd': 'Page.setDownloadBehavior', 'params': {'behavior': 'allow', 'downloadPath': "/content"}}

command_result = d.execute("send_command", params)

for i in ticker_test:
  print(i)
  url = (r'http://financials.morningstar.com/ratios/' +
               r'r.html?&t=' + i +
               r'&region=' + region +
               r'&culture=' + culture +
               r'&cur=' + currency)
  print(url)
  xpath="//span[@class='csv']"
  d.get(url)
  download = d.find_element_by_xpath(xpath).click()
# Out:
# XETR:MTX
# http://financials.morningstar.com/ratios/r.html?&t=XETR:MTX&region=usa&culture=en-US&cur=EUR

# %%
# !ls
# !pwd
# Out:
# 'Copy of good_morning.py'   good_morning.py	  sample_data
#  gdrive			   'MTX Key Ratios.csv'
#  good_download.py	    __pycache__
# /content

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !mv *.csv gdrive/My\ Drive/Colab\ Notebooks/Shared/Stock_Data
